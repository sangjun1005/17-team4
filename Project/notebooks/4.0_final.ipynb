# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\김양일\Desktop\Team_Project\data\processed\최종_취약지역_종합점수.csv")

print(df.head(10))
# Out:
#    우선순위    지역    구 유형     총계  65세이상  고령인구비율  독거노인수  독거노인비율_고령인구대비  심한장애인수  \
# 0     1    동면  동남구  면   1864   1020   54.72    285          27.94     153
# 1     2   성남면  동남구  면   2734   1328   48.57    308          23.19     179
# 2     3    북면  동남구  면   3976   1726   43.41    414          23.99     188
# 3     4   수신면  동남구  면   1982    946   47.73    221          23.36      60
# 4     5   광덕면  동남구  면   3950   1857   47.01    448          24.12     166
# 5     6  원성1동  동남구  동   7469   2316   31.01    492          21.24     215
# 6     7   병천면  동남구  면   5837   2056   35.22    494          24.03     192
# 7     8   입장면  서북구  면   7328   2750   37.53    659          23.96     190
# 8     9  원성2동  동남구  동   8493   2856   33.63    568          19.89     224
# 9    10  쌍용3동  서북구  동  16753   3286   19.61    746          22.70     554
#
#    ...  의료기관수  공공기관수  고령인구1000명당의료기관수  인구취약점수  의료취약점수  교통취약점수   종합점수  위험등급  \
# 0  ...      0      2             0.00   83.06   87.50   99.03  87.81     A
# ...
