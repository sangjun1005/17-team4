# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\김양일\Desktop\Team_Project\data\processed\01_인구_v1.csv")

print(df.head())
# Out:
#     지역 성별    총계  19세이하  20∼29  30∼39  40∼49  50∼59  60∼69  70∼79  80∼89  \
# 0   동면  계  1864     42     75     64    105    276    586    409    245
# 1  성남면  계  2734    131    167    118    204    447    761    568    268
# 2  수신면  계  1982     73    107    132    153    321    543    379    236
# 3  광덕면  계  3950    182    187    236    296    651   1154    769    365
# 4   북면  계  3976    199    231    239    361    680   1169    687    327
#
#    90∼99  100세이상  65세이상  85세이상  20세이상  고령인구비율
# 0     59       3   1020    169   1822   54.72
# 1     69       1   1328    182   2603   48.57
# 2     38       0    946    142   1909   47.73
# 3    110       0   1857    265   3768   47.01
# 4     81       2   1726    221   3777   43.41

# %%
print(df["고령인구비율"].describe())
# Out:
# count    34.000000
# mean     23.839412
# std      13.490575
# min       4.100000
# 25%      14.485000
# 50%      20.100000
# 75%      33.182500
# max      54.720000
# Name: 고령인구비율, dtype: float64

# %%
print(df["65세이상"].head(10))
print(df["고령인구비율"].head(10))
# Out:
# 0    1020
# 1    1328
# 2     946
# 3    1857
# 4    1726
# 5    1660
# 6    2750
# 7    2056
# 8    2856
# 9    6823
# Name: 65세이상, dtype: int64
# 0    54.72
# 1    48.57
# 2    47.73
# 3    47.01
# 4    43.41
# 5    37.77
# 6    37.53
# 7    35.22
# 8    33.63
# 9    31.84
# Name: 고령인구비율, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %%
plt.figure(figsize=(8, 4))

plt.bar(
    df["지역"],
    df["고령인구비율"]
)
plt.title("천안시 고령인구 비율")
plt.xlabel("지역")
plt.ylabel("고령인구 비율 (%)")
plt.xticks(rotation=90)

plt.show()

# %%
df_go = df.head(10)

plt.figure(figsize=(12, 8))
plt.bar(
    df_go["지역"],
    df_go["고령인구비율"],
    color = "#55A868"
)


plt.title("전안시 고령인구 비율 TOP10")
plt.xlabel("지역")
plt.ylabel("고령인구 비율(%)")
plt.xticks(rotation=70)

plt.grid(axis="y", alpha=0.5)

plt.savefig("고령인구 비율.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df65 = df.sort_values("65세이상", ascending=False).head(10)
print(df65)
# Out:
#       지역 성별      총계   19세이하  20∼29  30∼39   40∼49   50∼59  60∼69  70∼79  \
# 23   천안시  계  666182  110703  84409  98450  108687  111857  88331  41859
# 17   동남구  계  263653   39275  32380  33208   38667   46219  41287  21234
# 27   서북구  계  402529   71428  52029  65242   70020   65638  47044  20625
# 26   청룡동  계   59960   12101   6431   8671   10350   10079   7378   3355
# 9    성환읍  계   21430    2160   2225   1620    2522    4033   4301   2828
# 22   신안동  계   39066    5332   8484   5467    4859    5660   5355   2707
# 28   신방동  계   42607    7671   5138   5814    7559    8011   5253   2116
# 11   목천읍  계   21717    2583   2136   1815    2939    4762   4094   2035
# 30  부성1동  계   56813    8531  10632  11900    8626    8765   5346   2022
# 24  쌍용2동  계   33638    5346   5069   4193    4784    6480   4958   1889
#
#     80∼89  90∼99  100세이상   65세이상  85세이상   20세이상  고령인구비율
# 23  18232   3589      65  105051  10924  555479   15.77
# 17   9430   1916      37   52621   5709  224378   19.96
# 27   8802   1673      28   52430   5215  331101   13.03
# 26   1337    253       5    8386    736   47859   13.99
# 9    1460    274       7    6823    882   19270   31.84
# 22   1007    190       5    6486    596   33734   16.60
# 28    882    158       5    5449    517   34936   12.79
# 11   1090    254       9    5384    700   19134   24.79
# 30    835    153       3    5223    475   48282    9.19
# 24    756    162       1    4947    452   28292   14.71

# %%
plt.figure(figsize=(8, 4))
plt.bar(
    df65["지역"],
    df65["65세이상"]
)
plt.title("천안시 65세 이상 인구 TOP10")
plt.xlabel("지역")
plt.ylabel("65세 이상 인구")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.5)
plt.show()

# %%
df_region = df[
    ~df["지역"].isin(["천안시", "동남구", "서북구"])
].copy()

# %%
df_region65_top10 = df_region.sort_values("65세이상", ascending=False).head(10)
plt.figure(figsize=(12, 8))
plt.bar(
    df_region65_top10["지역"],
    df_region65_top10["65세이상"],
    color = "#55A868"
)
plt.title("천안시 65세 이상 인구 TOP10")
plt.xlabel("지역")
plt.ylabel("65세 이상 인구")
plt.xticks(rotation=70)
plt.grid(axis="y", alpha=0.5)

plt.savefig("65세 이상 인구.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
print(df_region[["지역", "65세이상", "고령인구비율"]].head(10))
print(df_region.shape)
# Out:
#      지역  65세이상  고령인구비율
# 0    동면   1020   54.72
# 1   성남면   1328   48.57
# 2   수신면    946   47.73
# 3   광덕면   1857   47.01
# 4    북면   1726   43.41
# 5   중앙동   1660   37.77
# 6   입장면   2750   37.53
# 7   병천면   2056   35.22
# 8  원성2동   2856   33.63
# 9   성환읍   6823   31.84
# (31, 17)

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

avg_rate = df_region["고령인구비율"].mean()
avg_old = df_region["65세이상"].mean()

plt.figure(figsize=(10, 7))
plt.scatter(
    df_region["고령인구비율"],
    df_region["65세이상"]
)

for _, row in df_region.iterrows():
    plt.text(
        row["고령인구비율"] + 0.3,
        row["65세이상"] + 50,
        row["지역"],
        fontsize = 8
    )
    
plt.title("천안시 고령인구 비율과 65세 이상 인구의 관계")
plt.xlabel("고령인구 비율(%)")
plt.ylabel("65세 이상 인구 수")
plt.grid(alpha=0.3)

plt.axvline(avg_rate, color="red", linestyle="--")
plt.axhline(avg_old, color="blue", linestyle="--")

# plt.savefig("고령인구 비율과 65세이상 인구의 관계.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
def classify_region(row):
    if row["고령인구비율"] >= avg_rate and row["65세이상"] >= avg_old:
        return "고비율·대규모"
    elif row["고령인구비율"] >= avg_rate:
        return "고비율·소규모"
    elif row["65세이상"] >= avg_old:
        return "저비율·대규모"
    else:
        return "저비율·소규모"

df_region["인구유형"] = df_region.apply(classify_region, axis=1)

print(df_region[["지역", "65세이상", "고령인구비율", "인구유형"]].sort_values(["인구유형", "고령인구비율"], ascending=[True, False]))
# Out:
#       지역  65세이상  고령인구비율     인구유형
# 9    성환읍   6823   31.84  고비율·대규모
# 11   목천읍   5384   24.79  고비율·대규모
# 0     동면   1020   54.72  고비율·소규모
# 1    성남면   1328   48.57  고비율·소규모
# 2    수신면    946   47.73  고비율·소규모
# 3    광덕면   1857   47.01  고비율·소규모
# 4     북면   1726   43.41  고비율·소규모
# 5    중앙동   1660   37.77  고비율·소규모
# 6    입장면   2750   37.53  고비율·소규모
# 7    병천면   2056   35.22  고비율·소규모
# 8   원성2동   2856   33.63  고비율·소규모
# 10  원성1동   2316   31.01  고비율·소규모
# 13  성정1동   3727   22.21  저비율·대규모
# 15   봉명동   3498   20.52  저비율·대규모
# 16   직산읍   3837   20.24  저비율·대규모
# 18   성거읍   4218   19.83  저비율·대규모
# 20   일봉동   4144   17.11  저비율·대규모
# 22   신안동   6486   16.60  저비율·대규모
# 24  쌍용2동   4947   14.71  저비율·대규모
# 25  성정2동   3518   14.41  저비율·대규모
# 26   청룡동   8386   13.99  저비율·대규모
# 28   신방동   5449   12.79  저비율·대규모
# 29   백석동   3754    9.32  저비율·대규모
# 30  부성1동   5223    9.19  저비율·대규모
# 32  부성2동   3737    5.85  저비율·대규모
# 12  쌍용1동   2848   23.39  저비율·소규모
# 14   풍세면   2216   20.99  저비율·소규모
# 19  쌍용3동   3286   19.61  저비율·소규모
# 21   문성동   1293   16.61  저비율·소규모
# 31  불당1동   2234    7.08  저비율·소규모
# 33  불당2동   1528    4.10  저비율·소규모

# %%
plt.figure(figsize=(12, 8))

highlight = ["성환읍", "목천읍", "청룡동", "동면"]

for _, row in df_region.iterrows():
    if row["지역"] in highlight:
        plt.scatter(
            row["고령인구비율"],
            row["65세이상"],
            color="red",
            s=100
        )
        
        plt.text(
            row["고령인구비율"] + 0.5,
            row["65세이상"] + 50,
            row["지역"],
            fontsize=9
        )

    else:
        plt.scatter(
            row["고령인구비율"],
            row["65세이상"],
            color="gray",
            s=40
        )


        plt.text(
            avg_rate + 1,
            df_region["65세이상"].max() * 1,
            "고비율·대규모",
            fontsize=11
        )

        plt.text(
            avg_rate + 1,
            df_region["65세이상"].min(),
            "고비율·소규모",
            fontsize=11
        )

        plt.text(
            df_region["고령인구비율"].min(),
            df_region["65세이상"].max() * 1,
            "저비율·대규모",
            fontsize=11
        )

        plt.text(
            df_region["고령인구비율"].min(),
            df_region["65세이상"].min(),
            "저비율·소규모",
            fontsize=11
        )


    
plt.title("천안시 고령인구 비율과 65세 이상 인구의 관계")
plt.xlabel("고령인구 비율(%)")
plt.ylabel("65세 이상 인구 수")
plt.grid(alpha=0.3)

plt.axvline(
    avg_rate,
    color="red",
    linestyle="--",
    label="평균 고령인구비율"
)

plt.axhline(
    avg_old,
    color="blue",
    linestyle="--",
    label="평균 고령인구수"
)

plt.legend()

plt.savefig("고령인구 비율과 65세이상 인구의 관계.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
print(df_region.head())
# Out:
#     지역 성별    총계  19세이하  20∼29  30∼39  40∼49  50∼59  60∼69  70∼79  80∼89  \
# 0   동면  계  1864     42     75     64    105    276    586    409    245
# 1  성남면  계  2734    131    167    118    204    447    761    568    268
# 2  수신면  계  1982     73    107    132    153    321    543    379    236
# 3  광덕면  계  3950    182    187    236    296    651   1154    769    365
# 4   북면  계  3976    199    231    239    361    680   1169    687    327
#
#    90∼99  100세이상  65세이상  85세이상  20세이상  고령인구비율     인구유형
# 0     59       3   1020    169   1822   54.72  고비율·소규모
# 1     69       1   1328    182   2603   48.57  고비율·소규모
# 2     38       0    946    142   1909   47.73  고비율·소규모
# 3    110       0   1857    265   3768   47.01  고비율·소규모
# 4     81       2   1726    221   3777   43.41  고비율·소규모

# %%
df_region.to_csv(
    r"C:\Users\김양일\Desktop\팀프로젝트\data\processed\인구_v2.csv",
    index=False,
    encoding="utf-8-sig"
)
